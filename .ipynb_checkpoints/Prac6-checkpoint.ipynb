# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
df = pd.read_csv("CSV Files/Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
sns.boxplot(df["SepalLengthCm"])
# Out:
# <Axes: ylabel='SepalLengthCm'>

# %%
sns.boxplot(df["SepalWidthCm"])
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
sns.boxplot(df["PetalLengthCm"])
# Out:
# <Axes: ylabel='PetalLengthCm'>

# %%
sns.boxplot(df["PetalLengthCm"])
# Out:
# <Axes: ylabel='PetalLengthCm'>

# %%
df[df["Species"] == "Iris-setosa"]["SepalLengthCm"].count()
# Out:
# np.int64(50)

# %%
df[df["Species"] == "Iris-virginica"]["SepalLengthCm"].count()
# Out:
# np.int64(50)

# %%
df[df["Species"] == "Iris-versicolor"]["SepalLengthCm"].count()
# Out:
# np.int64(50)

# %%
df.plot(xlabel = 'Species',ylabel = 'Iris')
# Out:
# <Axes: xlabel='Species', ylabel='Iris'>

# %%
df.plot(x='Species', y='PetalWidthCm', kind='bar')
plt.show()

# %%
df.plot(x='Species', y='PetalLengthCm', kind='bar')
plt.show()

# %%
df.plot(x='Species', y='SepalWidthCm', kind='bar')
plt.show()

# %%
df.plot(x='Species', y='SepalLengthCm', kind='bar')
plt.show()

# %% [markdown]
# ### Iris-setosa = 1
# ### Iris-virginica = 2
# ### Iris-versicolor = 3
# ### Updating species to use 1,2,3 numerics instead of strings

# %%
df.plot.scatter('Species',['SepalLengthCm'])
# Out:
# <Axes: xlabel='Species', ylabel='[SepalLengthCm]'>

# %%
df.plot('Species',['SepalWidthCm'],kind='scatter')
# Out:
# <Axes: xlabel='Species', ylabel='[SepalWidthCm]'>

# %%
df.plot('Species',['PetalWidthCm'],kind='scatter')
# Out:
# <Axes: xlabel='Species', ylabel='[PetalWidthCm]'>

# %%
df.plot('Species',['PetalLengthCm'],kind='scatter')
# Out:
# <Axes: xlabel='Species', ylabel='[PetalLengthCm]'>

# %%
df.plot(x='SepalLengthCm',y='SepalWidthCm',kind='scatter')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
df.plot(x='PetalLengthCm',y='PetalWidthCm',kind='scatter')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.FacetGrid(df, hue="Species", height=5).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()

# %%
sns.boxplot(x="Species",y="PetalLengthCm",data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
#Violin plot
ax=sns.boxplot(x="Species",y="PetalLengthCm",data=df)
ax=sns.stripplot(x="Species",y="PetalLengthCm",data=df,jitter=True,edgecolor="Gray")

# %%
sns.boxplot(x="Species",y="PetalWidthCm",data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
#Violin plot
ay=sns.boxplot(x="Species",y="PetalWidthCm",data=df)
ay=sns.stripplot(x="Species",y="PetalWidthCm",data=df,jitter=True,edgecolor="Gray")

# %%
sns.violinplot(x="Species",y="PetalLengthCm",data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.violinplot(x="Species",y="PetalWidthCm",data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.violinplot(x="PetalLengthCm",y="Species",data=df)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Species'>

# %%
sns.FacetGrid(df,hue="Species",height=6).map(sns.kdeplot,"PetalLengthCm").add_legend()

# %%
sns.FacetGrid(df,hue="Species",height=6).map(sns.kdeplot,"PetalWidthCm").add_legend()

# %%
#PairPlot
sns.pairplot(df.drop("Id",axis=1),hue="Species",height=3)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=0)
print("The Dataset is Splitted Successfully")
# Out:
# The Dataset is Splitted Successfully

# %%
#Train and check accuracy for each algorithm, for comparison
# logistic regression, k-nearest neighbour, support vector machine, decision trees, naive bias algo

# %%
#Logistic Regression
#feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(random_state = 0)
log_reg.fit(x_train,y_train)

print("Logistic Regression Fitted Successfully")
# Out:
# Logistic Regression Fitted Successfully

# %%
#predict test set results
y_p = log_reg.predict(x_test)
print("Predicted Test Set Results")
# Out:
# Predicted Test Set Results

# %%
#making confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_p)
tp = cm[0][0]
fp = cm[0][1]
fn = cm[1][0]
tn = cm[1][1]
print(cm)
# Out:
# [[13  0  0]
#  [ 0 16  0]
#  [ 0  0  9]]

# %%
accuracy = (tp + tn)/(tp +fp + tn + fn)
print(accuracy*100)

error_r = (fp+fn) / (tp+tn)
print(error_r*100)

prec = tp / (tp+fp)
print(prec*100)

rec = tp / (tp+fn)
print(rec*100)
# Out:
# 100.0
# 0.0
# 100.0
# 100.0

# %%
#Naive bias algo has higest accuracy -> Gaussian NB Perfect accuracy (Most Optimized)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      1.00      1.00        16
#  Iris-virginica       1.00      1.00      1.00         9
#
#        accuracy                           1.00        38
#       macro avg       1.00      1.00      1.00        38
#    weighted avg       1.00      1.00      1.00        38

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[13  0  0]
#  [ 0 16  0]
#  [ 0  0  9]]

# %%
from sklearn.metrics import accuracy_score
print('Accuracy is',accuracy_score(y_pred,y_test) * 100)
# Out:
# Accuracy is 100.0
