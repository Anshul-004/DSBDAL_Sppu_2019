# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Users/91997/Desktop/CSV/iris_dataset.csv')

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print("Column Names and Data Types:\n")
print(data.dtypes)
# Out:
# Column Names and Data Types:
#
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# dtype: object

# %%
data.hist(figsize=(10, 8), edgecolor='black')
plt.suptitle("Histograms for Iris Features", fontsize=16)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(2, 5))
for i, column in enumerate(data.select_dtypes(include='float').columns, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 plt.figure(figsize=(2, 5))
# ----> 2 for i, column in enumerate(df.select_dtypes(include='float').columns, 1):
#       3     plt.subplot(2, 2, i)
#       4     sns.boxplot(x=df[column])
#
# NameError: name 'df' is not defined
